# %%
import solara
import os
if os.name != 'nt' :
    import resource
#%matplotlib widget
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, HTML
from App.common import V, init_globals, loading_bar, myfigures, get_query_list, mp, tabs_out, tabs_html
from App import tab1, tab2, tab3, tab4, tab5, tab6, tab7
import dmyplant2 as dmp2
import logging
import shutil

logfilename = 'FSM.log'
if os.path.exists(logfilename):
    shutil.copyfile(logfilename,logfilename[:-4] + '_bak.log')

logging.basicConfig(
    filename=logfilename,
    filemode='w',
    format='%(asctime)s %(levelname)s %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    level=logging.ERROR
)
logging.info("FSM logging Start")
# Out:
# <div class="jupyter-widget-checks-container">
#     <script>
#         (function () {
#             console.log("Checking for jupyter-widgets extensions")
#             const inLab = window._JUPYTERLAB !== undefined;
#             const silent = jupyter_widget_checks_silent;
#             const containers = document.getElementsByClassName('jupyter-widget-checks-container');
#             const rootEl = containers[containers.length - 1];
#             const libraries = window.jupyter_widget_checks_libraries;
#
#             function getBaseUrl() {
#                 const labConfigData = document.getElementById("jupyter-config-data");
#                 if (labConfigData) {
#                     /* lab and Voila */
#                     return JSON.parse(labConfigData.textContent).baseUrl;
#                 }
#                 let base = document.body.dataset.baseUrl || document.baseURI;
#                 return base;
#             }
#
#             function checkLibrary(extensions, library) {
#                 let installed = false;
#                 let ok = true;
#                 if (inLab) {
#                     installed = _JUPYTERLAB[library.lab] !== undefined
#                 } else {
#                     installed = extensions[library.classic] !== undefined;
#                     let enabled = extensions[library.classic] === true;
#                 }
#                 const div = document.createElement("div")
#                 if (installed) {
#                     if (!silent) {
#                         div.innerHTML = `Extension ${library.python} is installed at the server ✅`
#                         rootEl.appendChild(div)
#                     }
#                 } else {
#                     div.innerHTML = `Extension ${library.python} is <b>NOT</b> installed at the server ❌.`
#                     rootEl.appendChild(div)
#                     ok = false;
#                 }
#                 return ok;
#             }
#
#             async function check() {
#                 const url = `${getBaseUrl()}api/config/notebook`
#                 const response = (await fetch(url));
#                 const data = await response.json()
#                 const extensions = data["load_extensions"];
#                 var ok = true;
#                 let needsInstall = [];
#                 libraries.forEach((library) => {
#                     if (!checkLibrary(extensions, library)) {
#                         ok = false;
#                         needsInstall.push(library.python)
#                         console.log("Needs install", library.python)
#                     }
#                 })
#                 console.log(ok, needsInstall)
#                 if (!ok) {
#                     const div = document.createElement("div")
#                     const div2 = document.createElement("div")
#                     div.innerHTML = `Run <code>${jupyter_python_executable} -m pip install ${needsInstall.join(" ")}</code>. Refresh the page after installation.`
#                     div2.innerHTML = `Visit <a href="https://solara.dev/docs/troubleshoot" target="_blank">https://solara/dev/docs/troubleshoot</a> for more information.`
#                     rootEl.appendChild(div)
#                     rootEl.appendChild(div2)
#                 }
#             }
#             check()
#         })();
#     </script>
# </div>
# c:\Users\chvatdi00\Documents\Scripts\dstatemachine/App/figures.json, existiert ? True
# {'actuators': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                 'color': ['lightblue', 'red'],
#                 'unit': 'kW',
#                 'ylim': 'func_power'},
#                {'col': ['Various_Values_SpeedAct'],
#                 'color': 'blue',
#                 'unit': 'rpm',
#                 'ylim': [0, 2500]},
#                {'col': ['Ignition_ITPAvg'],
#                 'color': 'rgba(255,0,255,0.4)',
#                 'unit': '°KW',
#                 'ylim': [-10, 30]},
#                {'col': ['TecJet_Lambda1'],
#                 'color': 'rgba(255,165,0,0.4)',
#                 'unit': '-',
#                 'ylim': [0, 3]},
#                {'_ylim': [0, 3],
#                 'col': ['Aux_PreChambDifPress'],
#                 'color': 'purple',
#                 'unit': '-'},
#                {'col': ['TecJet_Lambda1'],
#                 'color': 'rgba(255,165,0,0.4)',
#                 'unit': '-',
#                 'ylim': [0, 3]},
#                {'_ylim': [0, 3],
#                 'col': ['Various_Values_PressBoost'],
#                 'color': 'dodgerblue',
#                 'unit': 'bar'},
#                {'col': ['Various_Values_TempMixture'],
#                 'color': 'orange',
#                 'unit': '°C',
#                 'ylim': [0, 200]},
#                {'col': ['Aux_RoomTemp'],
#                 'color': 'hotpink',
#                 'unit': '°C',
#                 'ylim': [-50, 100]},
#                {'col': ['Various_Values_PosThrottle',
#                         'Various_Values_PosTurboBypass'],
#                 'color': ['rgba(105,105,105,0.6)', 'rgba(165,42,42,0.4)'],
#                 'unit': '%',
#                 'ylim': [-10, 110]}],
#  'ctr_10': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#              'color': ['lightblue', 'red'],
#              'unit': 'kW',
#              'ylim': 'func_power'},
#             {'col': ['Various_Values_SpeedAct'],
#              'color': 'blue',
#              'unit': 'rpm',
#              'ylim': [0, 2500]},
#             {'col': ['Hyd_TempWatRetPreEng', 'Hyd_TempWatRet'],
#              'color': ['hotpink', 'darkred'],
#              'unit': '°C',
#              'ylim': [0, 110]},
#             {'col': ['TecJet_Lambda1'],
#              'color': 'rgba(255,165,0,0.4)',
#              'unit': '-',
#              'ylim': [0, 3]},
#             {'col': ['CtrModule_Ctr10_X', 'CtrModule_Ctr10_W'],
#              'color': ['indianred', 'crimson'],
#              'unit': '°C',
#              'ylim': [0, 110]},
#             {'col': ['CtrModule_Ctr10_Y'],
#              'color': 'midnightblue',
#              'unit': '%',
#              'ylim': [0, 110]},
#             {'col': ['CtrModule_Ctr10_Error'],
#              'color': 'darkmagenta',
#              'unit': '%',
#              'ylim': [-100, 100]}],
#  'ctr_14': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#              'color': ['lightblue', 'red'],
#              'unit': 'kW',
#              'ylim': 'func_power'},
#             {'col': ['Various_Values_SpeedAct'],
#              'color': 'blue',
#              'unit': 'rpm',
#              'ylim': [0, 2500]},
#             {'col': ['Hyd_TempWatRetPreEng', 'Hyd_TempWatRet'],
#              'color': ['hotpink', 'darkred'],
#              'unit': '°C',
#              'ylim': [0, 110]},
#             {'col': ['TecJet_Lambda1'],
#              'color': 'rgba(255,165,0,0.4)',
#              'unit': '-',
#              'ylim': [0, 3]},
#             {'col': ['CtrModule_Ctr14_X', 'CtrModule_Ctr14_W'],
#              'color': ['brown', 'lightpink'],
#              'unit': '°C',
#              'ylim': [0, 110]},
#             {'col': ['CtrModule_Ctr14_Y'],
#              'color': 'gray',
#              'unit': '%',
#              'ylim': [0, 110]},
#             {'col': ['CtrModule_Ctr14_Error'],
#              'color': 'darkmagenta',
#              'unit': '%',
#              'ylim': [-100, 100]}],
#  'exh_detail': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                  'color': ['lightblue', 'red'],
#                  'unit': 'kW',
#                  'ylim': 'func_power'},
#                 {'col': ['Various_Values_SpeedAct'],
#                  'color': 'blue',
#                  'unit': 'rpm',
#                  'ylim': [0, 2500]},
#                 {'col': ['TecJet_Lambda1'],
#                  'color': 'rgba(255,165,0,0.4)',
#                  'unit': '-',
#                  'ylim': [0, 3]},
#                 {'col': ['func_cyl|Exhaust_TempCyl*',
#                          'Exhaust_TempCylMax',
#                          'Exhaust_TempCylMin'],
#                  'unit': '°C',
#                  'ylim': [300, 700]}],
#  'exhaust': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#               'color': ['lightblue', 'red'],
#               'unit': 'kW',
#               'ylim': 'func_power'},
#              {'col': ['Various_Values_SpeedAct'],
#               'color': 'blue',
#               'unit': 'rpm',
#               'ylim': [0, 2500]},
#              {'col': ['TecJet_Lambda1'],
#               'color': 'rgba(255,165,0,0.4)',
#               'unit': '-',
#               'ylim': [0, 3]},
#              {'col': ['Exhaust_TempHexIn'],
#               'color': 'purple',
#               'unit': '°C',
#               'ylim': [0, 700]},
#              {'col': ['func_cyl|Exhaust_TempCyl*',
#                       'Exhaust_TempCylMax',
#                       'Exhaust_TempCylMin'],
#               'unit': '°C',
#               'ylim': [0, 700]}],
#  'hydraulics': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                  'color': ['lightblue', 'red'],
#                  'unit': 'kW',
#                  'ylim': 'func_power'},
#                 {'col': ['Various_Values_SpeedAct'],
#                  'color': 'blue',
#                  'unit': 'rpm',
#                  'ylim': [0, 2500]},
#                 {'col': ['Hyd_PressCrankCase'],
#                  'color': 'orange',
#                  'unit': 'mbar',
#                  'ylim': [-100, 100]},
#                 {'col': ['Hyd_PressOilDif'],
#                  'color': 'black',
#                  'unit': 'bar',
#                  'ylim': [0, 3]},
#                 {'col': ['Hyd_PressOil'],
#                  'color': 'brown',
#                  'unit': 'bar',
#                  'ylim': [0, 10]},
#                 {'col': ['TecJet_Lambda1'],
#                  'color': 'rgba(255,165,0,0.4)',
#                  'unit': '-',
#                  'ylim': [0, 3]},
#                 {'col': ['Hyd_TempOil',
#                          'Hyd_TempCoolWat',
#                          'Hyd_TempWatRetPreEng',
#                          'Hyd_TempWatRet'],
#                  'color': ['#2171b5', 'orangered', 'hotpink', 'darkred'],
#                  'unit': '°C',
#                  'ylim': [0, 110]},
#                 {'col': ['Hyd_PressCoolWat'],
#                  'color': 'dodgerblue',
#                  'unit': 'bar',
#                  'ylim': [0, 10]}],
#  'ignition1': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                 'color': ['lightblue', 'red'],
#                 'unit': 'kW',
#                 'ylim': 'func_power'},
#                {'col': ['Various_Values_SpeedAct'],
#                 'color': 'blue',
#                 'unit': 'rpm',
#                 'ylim': [0, 2500]},
#                {'col': ['TecJet_Lambda1'],
#                 'color': 'rgba(255,165,0,0.4)',
#                 'unit': '-',
#                 'ylim': [0, 3]},
#                {'col': ['func_cyl|Monic_VoltCyl*'],
#                 'unit': 'kV',
#                 'ylim': [0, 100]}],
#  'ignition2': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                 'color': ['lightblue', 'red'],
#                 'unit': 'kW',
#                 'ylim': 'func_power'},
#                {'col': ['Various_Values_SpeedAct'],
#                 'color': 'blue',
#                 'unit': 'rpm',
#                 'ylim': [0, 2500]},
#                {'col': ['TecJet_Lambda1'],
#                 'color': 'rgba(255,165,0,0.4)',
#                 'unit': '-',
#                 'ylim': [0, 3]},
#                {'col': ['func_cyl|Ignition_ITPCyl*'],
#                 'unit': '°KW',
#                 'ylim': [0, 40]}],
#  'knocking': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                'color': ['lightblue', 'red'],
#                'unit': 'kW',
#                'ylim': 'func_power'},
#               {'col': ['Various_Values_SpeedAct'],
#                'color': 'blue',
#                'unit': 'rpm',
#                'ylim': [0, 2500]},
#               {'col': ['TecJet_Lambda1'],
#                'color': 'rgba(255,165,0,0.4)',
#                'unit': '-',
#                'ylim': [0, 3]},
#               {'col': ['func_cyl|Knock_KLS98_Knock_Cyl*'],
#                'unit': 'mv',
#                'ylim': [0, 1000]},
#               {'col': ['func_cyl|Knock_KLS98_IntKnock_Cyl*'],
#                'unit': '%',
#                'ylim': [-80, 10]}],
#  'tecjet': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#              'color': ['lightblue', 'red'],
#              'unit': 'kW',
#              'ylim': 'func_power'},
#             {'col': ['bmep'],
#              'color': 'orange',
#              'unit': 'bar',
#              'ylim': [-10, 40]},
#             {'col': ['Various_Values_SpeedAct'],
#              'color': 'blue',
#              'unit': 'rpm',
#              'ylim': [0, 2500]},
#             {'col': ['Ignition_ITPAvg'],
#              'color': 'limegreen',
#              'unit': '°KW',
#              'ylim': [-10, 30]},
#             {'col': ['TecJet_Lambda1'],
#              'color': 'rgba(255,165,0,0.4)',
#              'unit': '-',
#              'ylim': [0, 3]},
#             {'_ylim': [0, 3],
#              'col': ['TecJet_GasPress1'],
#              'color': 'rgba(255,0,0,0.4)',
#              'unit': 'mbar'},
#             {'_ylim': [0, 3],
#              'col': ['TecJet_GasTemp1'],
#              'color': 'rgba(255,0,255,0.4)',
#              'unit': '°C'},
#             {'_ylim': [0, 3],
#              'col': ['TecJet_GasDiffPress'],
#              'color': 'olive',
#              'unit': 'mbar'},
#             {'col': ['TecJet_ValvePos1'],
#              'color': 'purple',
#              'unit': '%',
#              'ylim': [0, 200]}],
#  'valvenoise': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                  'color': ['lightblue', 'red'],
#                  'unit': 'kW',
#                  'ylim': 'func_power'},
#                 {'col': ['Various_Values_SpeedAct'],
#                  'color': 'blue',
#                  'unit': 'rpm',
#                  'ylim': [0, 2500]},
#                 {'col': ['TecJet_Lambda1'],
#                  'color': 'rgba(255,165,0,0.4)',
#                  'unit': '-',
#                  'ylim': [0, 3]},
#                 {'col': ['Exhaust_TempHexIn'],
#                  'color': 'purple',
#                  'unit': '°C',
#                  'ylim': [0, 700]},
#                 {'col': ['func_cyl|Knock_Valve_Noise_Cyl*'],
#                  'unit': 'mV',
#                  'ylim': [0, 12000]}],
#  'various': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#               'color': ['lightblue', 'red'],
#               'unit': 'kW',
#               'ylim': 'func_power'},
#              {'col': ['Hyd_OilCount_Trend_OilConsumption',
#                       'RMD_ListBuffMAvgOilConsume_OilConsumption'],
#               'color': ['orange', 'rgba(255, 224, 130,0.8)'],
#               'unit': 'g/kWh',
#               'ylim': [0, 1]},
#              {'col': ['Aux_RoomTemp'],
#               'color': 'hotpink',
#               'unit': '°C',
#               'ylim': [-50, 100]},
#              {'col': ['CMU_rDPr_Ch_AirFilt', 'CMU_rDPr_BbFilt'],
#               'color': ['blue', 'dodgerblue'],
#               'unit': 'mbar',
#               'ylim': [-50, 50]},
#              {'col': ['Aux_rPr_Baro'],
#               'color': 'gray',
#               'unit': 'mbar',
#               'ylim': [900, 1100]}]}
# c:\Users\chvatdi00\Documents\Scripts\dstatemachine/App/figures.json, existiert ? True
# {'actuators': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                 'color': ['lightblue', 'red'],
#                 'unit': 'kW',
#                 'ylim': 'func_power'},
#                {'col': ['Various_Values_SpeedAct'],
#                 'color': 'blue',
#                 'unit': 'rpm',
#                 'ylim': [0, 2500]},
#                {'col': ['Ignition_ITPAvg'],
#                 'color': 'rgba(255,0,255,0.4)',
#                 'unit': '°KW',
#                 'ylim': [-10, 30]},
#                {'col': ['TecJet_Lambda1'],
#                 'color': 'rgba(255,165,0,0.4)',
#                 'unit': '-',
#                 'ylim': [0, 3]},
#                {'_ylim': [0, 3],
#                 'col': ['Aux_PreChambDifPress'],
#                 'color': 'purple',
#                 'unit': '-'},
#                {'col': ['TecJet_Lambda1'],
#                 'color': 'rgba(255,165,0,0.4)',
#                 'unit': '-',
#                 'ylim': [0, 3]},
#                {'_ylim': [0, 3],
#                 'col': ['Various_Values_PressBoost'],
#                 'color': 'dodgerblue',
#                 'unit': 'bar'},
#                {'col': ['Various_Values_TempMixture'],
#                 'color': 'orange',
#                 'unit': '°C',
#                 'ylim': [0, 200]},
#                {'col': ['Aux_RoomTemp'],
#                 'color': 'hotpink',
#                 'unit': '°C',
#                 'ylim': [-50, 100]},
#                {'col': ['Various_Values_PosThrottle',
#                         'Various_Values_PosTurboBypass'],
#                 'color': ['rgba(105,105,105,0.6)', 'rgba(165,42,42,0.4)'],
#                 'unit': '%',
#                 'ylim': [-10, 110]}],
#  'ctr_10': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#              'color': ['lightblue', 'red'],
#              'unit': 'kW',
#              'ylim': 'func_power'},
#             {'col': ['Various_Values_SpeedAct'],
#              'color': 'blue',
#              'unit': 'rpm',
#              'ylim': [0, 2500]},
#             {'col': ['Hyd_TempWatRetPreEng', 'Hyd_TempWatRet'],
#              'color': ['hotpink', 'darkred'],
#              'unit': '°C',
#              'ylim': [0, 110]},
#             {'col': ['TecJet_Lambda1'],
#              'color': 'rgba(255,165,0,0.4)',
#              'unit': '-',
#              'ylim': [0, 3]},
#             {'col': ['CtrModule_Ctr10_X', 'CtrModule_Ctr10_W'],
#              'color': ['indianred', 'crimson'],
#              'unit': '°C',
#              'ylim': [0, 110]},
#             {'col': ['CtrModule_Ctr10_Y'],
#              'color': 'midnightblue',
#              'unit': '%',
#              'ylim': [0, 110]},
#             {'col': ['CtrModule_Ctr10_Error'],
#              'color': 'darkmagenta',
#              'unit': '%',
#              'ylim': [-100, 100]}],
#  'ctr_14': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#              'color': ['lightblue', 'red'],
#              'unit': 'kW',
#              'ylim': 'func_power'},
#             {'col': ['Various_Values_SpeedAct'],
#              'color': 'blue',
#              'unit': 'rpm',
#              'ylim': [0, 2500]},
#             {'col': ['Hyd_TempWatRetPreEng', 'Hyd_TempWatRet'],
#              'color': ['hotpink', 'darkred'],
#              'unit': '°C',
#              'ylim': [0, 110]},
#             {'col': ['TecJet_Lambda1'],
#              'color': 'rgba(255,165,0,0.4)',
#              'unit': '-',
#              'ylim': [0, 3]},
#             {'col': ['CtrModule_Ctr14_X', 'CtrModule_Ctr14_W'],
#              'color': ['brown', 'lightpink'],
#              'unit': '°C',
#              'ylim': [0, 110]},
#             {'col': ['CtrModule_Ctr14_Y'],
#              'color': 'gray',
#              'unit': '%',
#              'ylim': [0, 110]},
#             {'col': ['CtrModule_Ctr14_Error'],
#              'color': 'darkmagenta',
#              'unit': '%',
#              'ylim': [-100, 100]}],
#  'exh_detail': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                  'color': ['lightblue', 'red'],
#                  'unit': 'kW',
#                  'ylim': 'func_power'},
#                 {'col': ['Various_Values_SpeedAct'],
#                  'color': 'blue',
#                  'unit': 'rpm',
#                  'ylim': [0, 2500]},
#                 {'col': ['TecJet_Lambda1'],
#                  'color': 'rgba(255,165,0,0.4)',
#                  'unit': '-',
#                  'ylim': [0, 3]},
#                 {'col': ['func_cyl|Exhaust_TempCyl*',
#                          'Exhaust_TempCylMax',
#                          'Exhaust_TempCylMin'],
#                  'unit': '°C',
#                  'ylim': [300, 700]}],
#  'exhaust': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#               'color': ['lightblue', 'red'],
#               'unit': 'kW',
#               'ylim': 'func_power'},
#              {'col': ['Various_Values_SpeedAct'],
#               'color': 'blue',
#               'unit': 'rpm',
#               'ylim': [0, 2500]},
#              {'col': ['TecJet_Lambda1'],
#               'color': 'rgba(255,165,0,0.4)',
#               'unit': '-',
#               'ylim': [0, 3]},
#              {'col': ['Exhaust_TempHexIn'],
#               'color': 'purple',
#               'unit': '°C',
#               'ylim': [0, 700]},
#              {'col': ['func_cyl|Exhaust_TempCyl*',
#                       'Exhaust_TempCylMax',
#                       'Exhaust_TempCylMin'],
#               'unit': '°C',
#               'ylim': [0, 700]}],
#  'hydraulics': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                  'color': ['lightblue', 'red'],
#                  'unit': 'kW',
#                  'ylim': 'func_power'},
#                 {'col': ['Various_Values_SpeedAct'],
#                  'color': 'blue',
#                  'unit': 'rpm',
#                  'ylim': [0, 2500]},
#                 {'col': ['Hyd_PressCrankCase'],
#                  'color': 'orange',
#                  'unit': 'mbar',
#                  'ylim': [-100, 100]},
#                 {'col': ['Hyd_PressOilDif'],
#                  'color': 'black',
#                  'unit': 'bar',
#                  'ylim': [0, 3]},
#                 {'col': ['Hyd_PressOil'],
#                  'color': 'brown',
#                  'unit': 'bar',
#                  'ylim': [0, 10]},
#                 {'col': ['TecJet_Lambda1'],
#                  'color': 'rgba(255,165,0,0.4)',
#                  'unit': '-',
#                  'ylim': [0, 3]},
#                 {'col': ['Hyd_TempOil',
#                          'Hyd_TempCoolWat',
#                          'Hyd_TempWatRetPreEng',
#                          'Hyd_TempWatRet'],
#                  'color': ['#2171b5', 'orangered', 'hotpink', 'darkred'],
#                  'unit': '°C',
#                  'ylim': [0, 110]},
#                 {'col': ['Hyd_PressCoolWat'],
#                  'color': 'dodgerblue',
#                  'unit': 'bar',
#                  'ylim': [0, 10]}],
#  'ignition1': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                 'color': ['lightblue', 'red'],
#                 'unit': 'kW',
#                 'ylim': 'func_power'},
#                {'col': ['Various_Values_SpeedAct'],
#                 'color': 'blue',
#                 'unit': 'rpm',
#                 'ylim': [0, 2500]},
#                {'col': ['TecJet_Lambda1'],
#                 'color': 'rgba(255,165,0,0.4)',
#                 'unit': '-',
#                 'ylim': [0, 3]},
#                {'col': ['func_cyl|Monic_VoltCyl*'],
#                 'unit': 'kV',
#                 'ylim': [0, 100]}],
#  'ignition2': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                 'color': ['lightblue', 'red'],
#                 'unit': 'kW',
#                 'ylim': 'func_power'},
#                {'col': ['Various_Values_SpeedAct'],
#                 'color': 'blue',
#                 'unit': 'rpm',
#                 'ylim': [0, 2500]},
#                {'col': ['TecJet_Lambda1'],
#                 'color': 'rgba(255,165,0,0.4)',
#                 'unit': '-',
#                 'ylim': [0, 3]},
#                {'col': ['func_cyl|Ignition_ITPCyl*'],
#                 'unit': '°KW',
#                 'ylim': [0, 40]}],
#  'knocking': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                'color': ['lightblue', 'red'],
#                'unit': 'kW',
#                'ylim': 'func_power'},
#               {'col': ['Various_Values_SpeedAct'],
#                'color': 'blue',
#                'unit': 'rpm',
#                'ylim': [0, 2500]},
#               {'col': ['TecJet_Lambda1'],
#                'color': 'rgba(255,165,0,0.4)',
#                'unit': '-',
#                'ylim': [0, 3]},
#               {'col': ['func_cyl|Knock_KLS98_Knock_Cyl*'],
#                'unit': 'mv',
#                'ylim': [0, 1000]},
#               {'col': ['func_cyl|Knock_KLS98_IntKnock_Cyl*'],
#                'unit': '%',
#                'ylim': [-80, 10]}],
#  'tecjet': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#              'color': ['lightblue', 'red'],
#              'unit': 'kW',
#              'ylim': 'func_power'},
#             {'col': ['bmep'],
#              'color': 'orange',
#              'unit': 'bar',
#              'ylim': [-10, 40]},
#             {'col': ['Various_Values_SpeedAct'],
#              'color': 'blue',
#              'unit': 'rpm',
#              'ylim': [0, 2500]},
#             {'col': ['Ignition_ITPAvg'],
#              'color': 'limegreen',
#              'unit': '°KW',
#              'ylim': [-10, 30]},
#             {'col': ['TecJet_Lambda1'],
#              'color': 'rgba(255,165,0,0.4)',
#              'unit': '-',
#              'ylim': [0, 3]},
#             {'_ylim': [0, 3],
#              'col': ['TecJet_GasPress1'],
#              'color': 'rgba(255,0,0,0.4)',
#              'unit': 'mbar'},
#             {'_ylim': [0, 3],
#              'col': ['TecJet_GasTemp1'],
#              'color': 'rgba(255,0,255,0.4)',
#              'unit': '°C'},
#             {'_ylim': [0, 3],
#              'col': ['TecJet_GasDiffPress'],
#              'color': 'olive',
#              'unit': 'mbar'},
#             {'col': ['TecJet_ValvePos1'],
#              'color': 'purple',
#              'unit': '%',
#              'ylim': [0, 200]}],
#  'valvenoise': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#                  'color': ['lightblue', 'red'],
#                  'unit': 'kW',
#                  'ylim': 'func_power'},
#                 {'col': ['Various_Values_SpeedAct'],
#                  'color': 'blue',
#                  'unit': 'rpm',
#                  'ylim': [0, 2500]},
#                 {'col': ['TecJet_Lambda1'],
#                  'color': 'rgba(255,165,0,0.4)',
#                  'unit': '-',
#                  'ylim': [0, 3]},
#                 {'col': ['Exhaust_TempHexIn'],
#                  'color': 'purple',
#                  'unit': '°C',
#                  'ylim': [0, 700]},
#                 {'col': ['func_cyl|Knock_Valve_Noise_Cyl*'],
#                  'unit': 'mV',
#                  'ylim': [0, 12000]}],
#  'various': [{'col': ['Power_SetPower', 'Power_PowerAct'],
#               'color': ['lightblue', 'red'],
#               'unit': 'kW',
#               'ylim': 'func_power'},
#              {'col': ['Hyd_OilCount_Trend_OilConsumption',
#                       'RMD_ListBuffMAvgOilConsume_OilConsumption'],
#               'color': ['orange', 'rgba(255, 224, 130,0.8)'],
#               'unit': 'g/kWh',
#               'ylim': [0, 1]},
#              {'col': ['Aux_RoomTemp'],
#               'color': 'hotpink',
#               'unit': '°C',
#               'ylim': [-50, 100]},
#              {'col': ['CMU_rDPr_Ch_AirFilt', 'CMU_rDPr_BbFilt'],
#               'color': ['blue', 'dodgerblue'],
#               'unit': 'mbar',
#               'ylim': [-50, 50]},
#              {'col': ['Aux_rPr_Baro'],
#               'color': 'gray',
#               'unit': 'mbar',
#               'ylim': [900, 1100]}]}

# %% [markdown]
# ### MyPlant Statemachine Engine Analysis ©2023 Dieter Chvatal

# %%
#########################################
# tabs
#########################################
class App():
    def __init__(self):
        
        self.tab_objects_list = [
            tab1.Tab(),
            tab2.Tab(),
            tab3.Tab(),
            tab4.Tab(),
            tab5.Tab(),
            #tab6.Tab(),
            #tab7.Tab()
        ]

        self.tabs = widgets.Tab()
        self.tabs.observe(self.tabs_change_index, 'selected_index')

        self.set_children()
        self.set_titles()

        self.tab_objects_list[0].selected() # preselect the first tab.

    def show(self):
        display(
            widgets.VBox([
                self.tabs,
                tabs_out,
                tabs_html])
            );

    def set_children(self):
        self.tabs.children = [t.tab for t in self.tab_objects_list]

    def set_titles(self):
        for i,t in enumerate(self.tab_objects_list):
            self.tabs.set_title(i,t.title)

    def clear_all(self):
        for t in self.tab_objects_list:
            t.cleartab()

    def tabs_change_index(self, *args):  # the tabs callback
        self.tab_objects_list[self.tabs.selected_index].selected()

V.app = App()
V.app.show()
# Out:
# VBox(children=(Tab(children=(VBox(children=(Accordion(children=(HBox(children=(Button(description='Load', styl…
