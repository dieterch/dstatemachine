# %%
import dmyplant2
dmyplant2.cred()
try:
    mp = dmyplant2.MyPlant(0)
    mp.login()
    print('\nLogin successful')
except Exception as e:
    print('Login Credentials not accepted.')
# Out:
# Please enter your myPlant login:
# --------------------------------
# User:  dieter.chvatal@innio.com
# Password:  ········
# TOTP Secret:  ········
# downnload available dataItems & properties from Myplant,store locally.
#
# Login successful
