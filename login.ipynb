# %%
import dmyplant2
dmyplant2.cred()
try:
    mp = dmyplant2.MyPlant(0)
    mp.login()
    print('\nLogin successful')
except Exception as e:
    print('Login Credentials not accepted.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import dmyplant2
#       2 dmyplant2.cred()
#       3 try:
#       4     mp = dmyplant2.MyPlant(0)
#
# File ~\projects\dstatemachine\dmyplant2\__init__.py:7
#       5 from dmyplant2.support import cred, derive_key, tryagain
#       6 from dmyplant2.dMyplant import MyPlant, save_json, load_json
# ----> 7 from dmyplant2.dValidation import Validation #, HandleID
#       8 from dmyplant2.JFBokeh_Validation_DashBoard import ValidationDashboard
#       9 from dmyplant2.dEngine import Engine
#
# File ~\projects\dstatemachine\dmyplant2\dValidation.py:7
#       5 import sys
#       6 import logging
# ----> 7 from dmyplant2.dEngine import Engine
#       8 from dmyplant2.dMyplant import MyPlant, load_pkl, save_pkl
#       9 from pprint import pprint as pp
#
# File ~\projects\dstatemachine\dmyplant2\dEngine.py:9
# ...
